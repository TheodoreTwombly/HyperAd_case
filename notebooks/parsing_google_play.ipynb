# %%
# https://github.com/JoMingyu/google-play-scraper
# pip install google-play-scraper

from google_play_scraper import app

import pandas as pd

from tqdm.notebook import tqdm

from time import sleep

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/train.csv', usecols=['bundle', 'os'])

df = df[df['os'].isin(['Android', 'android'])].reset_index(drop=True)
df.drop(columns=['os'], inplace=True)

df.head()
# Out:
#                                   bundle
# 0                         com.MadOut.BIG
# 1  com.easybrain.solitaire.klondike.free
# 2   com.orbitalknight.ridiculousfreekick
# 3      tcouchgind.scooterextreme.scooter
# 4               com.FidgetTrading3D.game

# %%
# выберем уникальные значения
unique_bundles = df['bundle'].unique()

# освободим память
del df

# %%
print(len(unique_bundles))
# Out:
# 73271

# %%
# создадим датафрейм для хранения данных из парсера
pars_res_df = pd.DataFrame()

# создадим список для бандлов, на которых парсер не отработал
err_bundles = []

# %%
for app_bundle in tqdm(unique_bundles):

    try:
        result = app(
            app_bundle,
            lang='en', # defaults to 'en'
            country='ru' # defaults to 'us'
        )
        pars_res_df = pars_res_df.append(pd.DataFrame(pd.Series(result)).transpose()).reset_index(drop=True)
    except:
        err_bundles.append(app_bundle)
    
    #sleep(0.2)
# Out:
#   0%|          | 0/23271 [00:00<?, ?it/s]

# %% [markdown]
# # Соберем бакеты парсинга в один файл

# %%
import pandas as pd
import glob

path = r'../data/parsing_results' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
print(frame.shape)
frame.head()
# Out:
# (59369, 52)
#                              title  \
# 0            MadOut2 BigCityOnline
# 1               Solitaire Klondike
# 2                      Crazy Kick!
# 3  Fidget Trading 3D - Fidget Toys
# 4       Brain Wash - Thinking Game
#
#                                          description  \
# 0  Number one mobile game with open world! \r\n\r...
# 1  Solitaire is a time-tested classic card game e...
# 2  Get to the goal!\r\n\r\n\r\nOvertake your oppo...
# 3  Want to collect ALL The Fidgets In The World? ...
# 4  <b>How often do you talk to your brain?</b>\r\...
#
#                                      descriptionHTML  \
# 0  Number one mobile game with open world! <br><b...
# 1  Solitaire is a time-tested classic card game e...
# 2  Get to the goal!<br><br><br>Overtake your oppo...
# 3  Want to collect ALL The Fidgets In The World? ...
# 4  <b>How often do you talk to your brain?</b><br...
#
#                                              summary  \
# 0             Number One mobile game with open world
# 1  Klondike Solitaire is a classic card game to t...
# 2                          Dribble, shoot and score!
# 3                 Trade & Collect Satisfying Fidgets
# 4  Be smart! Train your brain and logic in over m...
#
#                                          summaryHTML     installs  \
# 0             Number One mobile game with open world  10,000,000+
# 1  Klondike Solitaire is a classic card game to t...   5,000,000+
# 2                          Dribble, shoot and score!  10,000,000+
# 3             Trade &amp; Collect Satisfying Fidgets  10,000,000+
# 4  Be smart! Train your brain and logic in over m...  50,000,000+
#
#    minInstalls     score   ratings  reviews  \
# 0   10000000.0  4.182135  591273.0  84059.0
# 1    5000000.0  4.372654   65158.0   1191.0
# 2   10000000.0  4.113662  149456.0   2051.0
# 3   10000000.0  3.415289  101655.0   1035.0
# 4   50000000.0  4.462635  287850.0   7228.0
#
#                               histogram  price  free currency   sale  \
# 0  [68210, 19167, 38791, 75642, 389463]    0.0  True      RUB  False
# 1       [5152, 1567, 3144, 9257, 46038]    0.0  True      RUB  False
# 2    [17156, 5999, 13030, 19735, 93536]    0.0  True      RUB  False
# 3    [23745, 8175, 13858, 13858, 42019]    0.0  True      RUB  False
# 4   [21905, 6597, 10702, 25809, 222837]    0.0  True      RUB  False
#
#    saleTime  originalPrice saleText  offersIAP  \
# 0       NaN            NaN      NaN       True
# 1       NaN            NaN      NaN       True
# 2       NaN            NaN      NaN       True
# 3       NaN            NaN      NaN      False
# 4       NaN            NaN      NaN       True
#
#                    inAppProductPrice                size androidVersion  \
# 0  RUB 75.00 - RUB 5,499.00 per item  Varies with device            4.4
# 1                RUB 479.00 per item                 77M            5.0
# 2    RUB 50.00 - RUB 259.00 per item                 53M            4.4
# 3                                NaN                 82M            5.0
# 4                RUB 269.00 per item                126M            4.4
#
#   androidVersionText     developer          developerId  \
# 0         4.4 and up  MadOut Games         MadOut+Games
# 1         5.0 and up     Easybrain  7473634688510685864
# 2         4.4 and up        VOODOO               VOODOO
# 3         5.0 and up      MagicLab             MagicLab
# 4         4.4 and up  SayGames Ltd  6392896734092635573
#
#                  developerEmail           developerWebsite  \
# 0      MadOutContacts@gmail.com    http://madoutgames.com/
# 1         support@easybrain.com   http://www.easybrain.com
# 2             support@voodoo.io      https://www.voodoo.io
# 3            cetciz@hotmail.com  http://www.maglab.com.tr/
# 4  brain_wash_android@say.games         https://say.games/
#
#                                     developerAddress  \
# 0                                  Kazakstan, Astana
# 1  3 Krinou street\nThe Oval, 6th Floor\nLimassol...
# 2                  4 rue Jules Lefebvre, 75009 Paris
# 3  Üniversiteler Mahallesi İhsan Doğramacı Bulvar...
# 4                                                NaN
#
#                                   privacyPolicy  developerInternalID   genre  \
# 0            http://www.madoutgames.com/privacy         5.592404e+18  Racing
# 1                 https://easybrain.com/privacy         7.473635e+18    Card
# 2                 https://www.voodoo.io/privacy         8.306042e+18  Arcade
# 3                  https://yildirim.me/privacy/         8.363139e+18  Casual
# 4  https://saygames.by/privacy-policy/brainwash         6.392897e+18  Puzzle
#
#        genreId                                               icon  \
# 0  GAME_RACING  https://play-lh.googleusercontent.com/2GjCUPLJ...
# 1    GAME_CARD  https://play-lh.googleusercontent.com/4lB-0lSR...
# 2  GAME_ARCADE  https://play-lh.googleusercontent.com/X26iLdhs...
# 3  GAME_CASUAL  https://play-lh.googleusercontent.com/aHhGDVFk...
# 4  GAME_PUZZLE  https://play-lh.googleusercontent.com/x-APduqO...
#
#                                          headerImage  \
# 0  https://play-lh.googleusercontent.com/3gYOTXU4...
# 1  https://play-lh.googleusercontent.com/FTlCtOhw...
# 2  https://play-lh.googleusercontent.com/3Iqn4A9w...
# 3  https://play-lh.googleusercontent.com/aJAYdiD6...
# 4  https://play-lh.googleusercontent.com/i5if9TfU...
#
#                                          screenshots  \
# 0  ['https://play-lh.googleusercontent.com/JQLpIT...
# 1  ['https://play-lh.googleusercontent.com/HMcSZA...
# 2  ['https://play-lh.googleusercontent.com/lhqXPO...
# 3  ['https://play-lh.googleusercontent.com/rEKVz9...
# 4  ['https://play-lh.googleusercontent.com/Vv20Xr...
#
#                                                video  \
# 0  https://www.youtube.com/embed/VhIBkdK0UII?ps=p...
# 1  https://www.youtube.com/embed/LQwkQ5_B-5I?ps=p...
# 2                                                NaN
# 3  https://www.youtube.com/embed/4D9QoKSf6Hs?ps=p...
# 4                                                NaN
#
#                                           videoImage  contentRating  \
# 0  https://play-lh.googleusercontent.com/3gYOTXU4...  Rated for 18+
# 1  https://play-lh.googleusercontent.com/FTlCtOhw...  Rated for 12+
# 2                                                NaN   Rated for 3+
# 3  https://play-lh.googleusercontent.com/aJAYdiD6...   Rated for 3+
# 4                                                NaN  Rated for 12+
#
#   contentRatingDescription adSupported  containsAds      released  \
# 0         Extreme Violence        True         True   May 1, 2017
# 1                   Nudity        True         True  May 19, 2021
# 2                      NaN        True         True  Aug 30, 2019
# 3                      NaN        True         True  Jun 29, 2021
# 4          Sexual Innuendo        True         True  Jun 30, 2020
#
#         updated version                                      recentChanges  \
# 0  1.620986e+09   10.27                               Improved performance
# 1  1.635255e+09   2.6.0  - New game mode added! Master your strategy to...
# 2  1.633098e+09  1.18.2                          - bugfixes & improvements
# 3  1.632132e+09   1.2.8  -New fidgets added\r\n-AI improvements\r\n-Bet...
# 4  1.627721e+09  1.30.0                internal improvements and bug fixes
#
#                                    recentChangesHTML  \
# 0                               Improved performance
# 1  - New game mode added! Master your strategy to...
# 2                      - bugfixes &amp; improvements
# 3  -New fidgets added<br>-AI improvements<br>-Bet...
# 4                internal improvements and bug fixes
#
#                                             comments  editorsChoice  \
# 0  ['*EDIT* This "Russian GTA" is sucks, just for...          False
# 1  ['As far as an app dedicated solely to solitai...          False
# 2  ["It's very good. I can handle the adds by tur...          False
# 3  ["This game is really nice I really like it bu...          False
# 4  ['It would be great if there were only 390 lev...          False
#
#                                          similarApps  \
# 0  ['com.gameloft.android.ANMP.GloftOLHM', 'com.g...
# 1  ['at.ner.SolitaireKlondike', 'com.easyfun.soli...
# 2  ['com.hyper.ballbrawl', 'com.masomo.headball2'...
# 3                      ['com.dobroapps.anti.stress']
# 4  ['com.playstrom.dop2', 'com.playstrom.bob', 'c...
#
#                                      moreByDeveloper  \
# 0                                                NaN
# 1                                                NaN
# 2  ['com.anvil.skirt', 'com.studio501.canvasrun',...
# 3  ['com.magiclab.insatiaio', 'com.magiclab.snail...
# 4                                                NaN
#
#                                    appId  \
# 0                         com.MadOut.BIG
# 1  com.easybrain.solitaire.klondike.free
# 2   com.orbitalknight.ridiculousfreekick
# 3               com.FidgetTrading3D.game
# 4                            com.hwg.sos
#
#                                                  url
# 0  https://play.google.com/store/apps/details?id=...
# 1  https://play.google.com/store/apps/details?id=...
# 2  https://play.google.com/store/apps/details?id=...
# 3  https://play.google.com/store/apps/details?id=...
# 4  https://play.google.com/store/apps/details?id=...

# %% [markdown]
# # Список нужных признаков:
# appId, title, description, summary, minInstalls, score, ratings, reviews, price, free, size, androidVersion, developer, genre, contentRating, contentRatingDescription, adSupported, containsAds,released, editorsChoice, moreByDeveloper

# %%
selected_features = ['appId',
                    'title',
                    'description',
                    'summary',
                    'minInstalls',
                    'score',
                    'ratings',
                    'reviews',
                    'price',
                    'free',
                    'size',
                    'androidVersion',
                    'developer',
                    'genre',
                    'contentRating',
                    'contentRatingDescription',
                    'adSupported',
                    'containsAds',
                    'released',
                    'editorsChoice',
                    'moreByDeveloper'
                    ]

frame = frame[selected_features]

# %%
frame.head()
# Out:
#                                    appId                            title  \
# 0                         com.MadOut.BIG            MadOut2 BigCityOnline
# 1  com.easybrain.solitaire.klondike.free               Solitaire Klondike
# 2   com.orbitalknight.ridiculousfreekick                      Crazy Kick!
# 3               com.FidgetTrading3D.game  Fidget Trading 3D - Fidget Toys
# 4                            com.hwg.sos       Brain Wash - Thinking Game
#
#                                          description  \
# 0  Number one mobile game with open world! \r\n\r...
# 1  Solitaire is a time-tested classic card game e...
# 2  Get to the goal!\r\n\r\n\r\nOvertake your oppo...
# 3  Want to collect ALL The Fidgets In The World? ...
# 4  <b>How often do you talk to your brain?</b>\r\...
#
#                                              summary  minInstalls     score  \
# 0             Number One mobile game with open world   10000000.0  4.182135
# 1  Klondike Solitaire is a classic card game to t...    5000000.0  4.372654
# 2                          Dribble, shoot and score!   10000000.0  4.113662
# 3                 Trade & Collect Satisfying Fidgets   10000000.0  3.415289
# 4  Be smart! Train your brain and logic in over m...   50000000.0  4.462635
#
#     ratings  reviews  price  free                size androidVersion  \
# 0  591273.0  84059.0    0.0  True  Varies with device            4.4
# 1   65158.0   1191.0    0.0  True                 77M            5.0
# 2  149456.0   2051.0    0.0  True                 53M            4.4
# 3  101655.0   1035.0    0.0  True                 82M            5.0
# 4  287850.0   7228.0    0.0  True                126M            4.4
#
#       developer   genre  contentRating contentRatingDescription adSupported  \
# 0  MadOut Games  Racing  Rated for 18+         Extreme Violence        True
# 1     Easybrain    Card  Rated for 12+                   Nudity        True
# 2        VOODOO  Arcade   Rated for 3+                      NaN        True
# 3      MagicLab  Casual   Rated for 3+                      NaN        True
# 4  SayGames Ltd  Puzzle  Rated for 12+          Sexual Innuendo        True
#
#    containsAds      released  editorsChoice  \
# 0         True   May 1, 2017          False
# 1         True  May 19, 2021          False
# 2         True  Aug 30, 2019          False
# 3         True  Jun 29, 2021          False
# 4         True  Jun 30, 2020          False
#
#                                      moreByDeveloper
# 0                                                NaN
# 1                                                NaN
# 2  ['com.anvil.skirt', 'com.studio501.canvasrun',...
# 3  ['com.magiclab.insatiaio', 'com.magiclab.snail...
# 4                                                NaN

# %% [markdown]
# # Подготовим некоторые признаки

# %%
# Преобразуем признак с другими играми издателя в их количество
frame['moreByDeveloper'] = frame['moreByDeveloper'].fillna('[]').apply(eval).apply(len)

# %%
# Преобразуем размер файла в целое число
frame['size'] = frame['size'].replace('Varies with device', '-1M')

frame['size'] = frame['size'].str.replace(',', '.').str.extract(r'(\d+[.\d]*)').astype(float)[0]

# %%
# Преобразуем версию андроида
frame['androidVersion'] = frame['androidVersion'].replace('Varies', '-1')

frame['androidVersion'] = frame['androidVersion'].str.split('.').str[0].str.extract(r'(\d+[.\d]*)').astype(float)[0]

# %%
# Преобразуем дату публикации и вытащим из нее признаки
frame['released'] = pd.to_datetime(frame['released'])

frame['release_day'] = frame['released'].dt.day
frame['release_month'] = frame['released'].dt.month
frame['release_year'] = frame['released'].dt.year

# удалим колонку с исходной датой
frame.drop(columns=['released'], inplace=True)

# %%
# Преобразуем оставшиеся булевы признаки в бинарный вид
for bool_feature in ['free', 'adSupported', 'containsAds', 'editorsChoice']:
    frame[bool_feature] = frame[bool_feature].fillna(-1000).astype(int)

# %%
# Почистим текстовые данные
frame['description'] = frame['description'].str.replace("\r\n", "", regex=True)\
    .str.replace("\t", "", regex=True)\
    .str.replace('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});', '')\
    .str.replace("["
        u"\U0001F600-\U0001F64F"  # emoticons
                u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                u"\U0001F680-\U0001F6FF"  # transport & map symbols
                u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                u"\U00002702-\U000027B0"
                u"\U000024C2-\U0001F251"
                u"\U0001f926-\U0001f937"
                u'\U00010000-\U0010ffff'
                u"\u200d"
                u"\u2640-\u2642"
                u"\u2600-\u2B55"
                u"\u23cf"
                u"\u23e9"
                u"\u231a"
                u"\u3030"
                u"\ufe0f"
       "]+", "", regex=True)

# %%
frame['summary'] = frame['summary'].str.replace("\r\n", "", regex=True)\
    .str.replace("\t", "", regex=True)\
    .str.replace('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});', '')\
    .str.replace("["
        u"\U0001F600-\U0001F64F"  # emoticons
                u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                u"\U0001F680-\U0001F6FF"  # transport & map symbols
                u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                u"\U00002702-\U000027B0"
                u"\U000024C2-\U0001F251"
                u"\U0001f926-\U0001f937"
                u'\U00010000-\U0010ffff'
                u"\u200d"
                u"\u2640-\u2642"
                u"\u2600-\u2B55"
                u"\u23cf"
                u"\u23e9"
                u"\u231a"
                u"\u3030"
                u"\ufe0f"
       "]+", "", regex=True)

# %%
frame.head()
# Out:
#                                    appId                            title  \
# 0                         com.MadOut.BIG            MadOut2 BigCityOnline
# 1  com.easybrain.solitaire.klondike.free               Solitaire Klondike
# 2   com.orbitalknight.ridiculousfreekick                      Crazy Kick!
# 3               com.FidgetTrading3D.game  Fidget Trading 3D - Fidget Toys
# 4                            com.hwg.sos       Brain Wash - Thinking Game
#
#                                          description  \
# 0  Number one mobile game with open world! Online...
# 1  Solitaire is a time-tested classic card game e...
# 2  Get to the goal!Overtake your opponents, move ...
# 3  Want to collect ALL The Fidgets In The World? ...
# 4  How often do you talk to your brain? Hey, frie...
#
#                                              summary  minInstalls     score  \
# 0             Number One mobile game with open world   10000000.0  4.182135
# 1  Klondike Solitaire is a classic card game to t...    5000000.0  4.372654
# 2                          Dribble, shoot and score!   10000000.0  4.113662
# 3                 Trade & Collect Satisfying Fidgets   10000000.0  3.415289
# 4  Be smart! Train your brain and logic in over m...   50000000.0  4.462635
#
#     ratings  reviews  price  free   size  androidVersion     developer  \
# 0  591273.0  84059.0    0.0     1    1.0             4.0  MadOut Games
# 1   65158.0   1191.0    0.0     1   77.0             5.0     Easybrain
# 2  149456.0   2051.0    0.0     1   53.0             4.0        VOODOO
# 3  101655.0   1035.0    0.0     1   82.0             5.0      MagicLab
# 4  287850.0   7228.0    0.0     1  126.0             4.0  SayGames Ltd
#
#     genre  contentRating contentRatingDescription  adSupported  containsAds  \
# 0  Racing  Rated for 18+         Extreme Violence            1            1
# 1    Card  Rated for 12+                   Nudity            1            1
# 2  Arcade   Rated for 3+                      NaN            1            1
# 3  Casual   Rated for 3+                      NaN            1            1
# 4  Puzzle  Rated for 12+          Sexual Innuendo            1            1
#
#    editorsChoice  moreByDeveloper  release_day  release_month  release_year
# 0              0                0          1.0            5.0        2017.0
# 1              0                0         19.0            5.0        2021.0
# 2              0                5         30.0            8.0        2019.0
# 3              0                5         29.0            6.0        2021.0
# 4              0                0         30.0            6.0        2020.0

# %%
# сохраним итоговый файл
frame.to_csv('../data/parsed_final.csv', index=False)
